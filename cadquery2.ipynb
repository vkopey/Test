# %% [markdown]
# <a href="https://colab.research.google.com/github/vkopey/Test/blob/main/cadquery2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cadquery
import cadquery as cq
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.0/151.0 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 MB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 34.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.7/423.7 kB 18.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.3/72.3 MB 7.6 MB/s eta 0:00:00
# ...

# %%
# !wget --no-cache --backups=1 https://raw.githubusercontent.com/vkopey/Test/main/cadquery_test.py
from cadquery_test import result
from IPython.core.display import display_svg
display_svg(result.toSvg(), raw=True)
# Out:
# --2024-05-12 20:05:44--  https://raw.githubusercontent.com/vkopey/Test/main/cadquery_test.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 160 [text/plain]
# Saving to: ‘cadquery_test.py’
#
# cadquery_test.py    100%[===================>]     160  --.-KB/s    in 0s
#
# 2024-05-12 20:05:44 (9.29 MB/s) - ‘cadquery_test.py’ saved [160/160]
